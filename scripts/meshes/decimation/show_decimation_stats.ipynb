# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
suzanne_df = pd.read_csv("./decimation_data/suzanne_results.csv")
sphere_df  = pd.read_csv("./decimation_data/sphere_results.csv")

# %%
suzanne_df
# Out:
#     reduction          mean       max           rms
# 0        0.99  1.134634e-07  0.000020  9.873838e-07
# 1        0.98  3.073482e-07  0.000028  1.885742e-06
# 2        0.97  5.772397e-07  0.000033  2.860960e-06
# 3        0.96  9.002386e-07  0.000040  3.819773e-06
# 4        0.95  1.259739e-06  0.000046  4.755772e-06
# ..        ...           ...       ...           ...
# 94       0.05  9.007085e-04  0.006145  1.173673e-03
# 95       0.04  1.111818e-03  0.006932  1.449207e-03
# 96       0.03  1.455003e-03  0.009643  1.895236e-03
# 97       0.02  2.125293e-03  0.013560  2.765844e-03
# 98       0.01  4.110266e-03  0.022375  5.365603e-03
#
# [99 rows x 4 columns]

# %%
sns.lineplot(suzanne_df,x="reduction", y="mean")
sns.lineplot(suzanne_df,x="reduction", y="max")
# Out:
# <Axes: xlabel='reduction', ylabel='mean'>

# %%
sns.lineplot(sphere_df,x="reduction", y="mean")
sns.lineplot(sphere_df,x="reduction", y="max")
# Out:
# <Axes: xlabel='reduction', ylabel='mean'>
